# %% [markdown]
# <a href="https://colab.research.google.com/github/kleczekr/tolkenizer/blob/master/scraping_avocado_post_2_retake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tabulate import tabulate
import pandas as pd

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
products = pd.read_csv('drive/My Drive/deite/avocado/wohnen.csv')
sales = pd.read_csv('drive/My Drive/deite/avocado/sales_randint.csv')
pageviews = pd.read_csv('drive/My Drive/deite/avocado/pageviews_randint.csv')

# %%
products.head(2)
# Out:
#                                                 name  ... category
# 0  \nKopfkissen Bio Lotus Natural®, Bio-Baumwolle...  ...   wohnen
# 1  \nGeschirrtuch aus Halbleinen mit Bio-Baumwoll...  ...   wohnen
#
# [2 rows x 9 columns]

# %%
sales.head(2)
# Out:
#    articles_sold  ...                                       article_name
# 0             83  ...  XL Set Vorratsgläser aus Glas mit Deckel aus 1...
# 1             94  ...  Wiederverwendbarer Lebensmittelbeutel ”Large” ...
#
# [2 rows x 5 columns]

# %%
pageviews.head(2)
# Out:
#    pageviews  ...                                               path
# 0        351  ...  /220612-xl-set-vorratsglaeser-aus-glas-mit-dec...
# 1        794  ...  /203165-wiederverwendbarer-lebensmittelbeutel-...
#
# [2 rows x 4 columns]

# %% [markdown]
# It seems that we can connect the sales data with the product data based on the name (product dataframe) and article_name (sales database), but we need to remove the newspace characters from the product data. While we are at it, we can also remove rows of newspace characters from some other columns in the product df.

# %%
# cleaning the line breaks
# some of the following lines look weird. we don't want to get rid of all of the
# newline characters. in most columns, we just want to convert multiple newline
# characters to a single newline character
products.name = products.name.str.replace(r'\n', '')
products.price = products.price.str.replace(r'\n\n\n\n', '\n')
products.price = products.price.str.replace(r'\n\n\n', '\n')
products.price = products.price.str.replace(r'\n\n', '\n')
products.postage = products.postage.str.replace(r'\n\n\n\n', '\n')
products.postage = products.postage.str.replace(r'\n\n\n', '\n')
products.postage = products.postage.str.replace(r'\n\n', '\n')
products.brand = products.brand.str.replace(r'\n', '')
products.description = products.description.str.replace(r'\n\n\n\n', '\n')
products.description = products.description.str.replace(r'\n\n\n', '\n')
products.description = products.description.str.replace(r'\n\n', '\n')
products.criteria = products.criteria.str.replace(r'\n\n\n\n', '\n')
products.criteria = products.criteria.str.replace(r'\n\n\n', '\n')
products.criteria = products.criteria.str.replace(r'\n\n', '\n')

# %% [markdown]
# When it comes to the pageview data, we can probably connect the two dataframes by the column link (product DF) = path (pageview DF). Notice that the path recorded in the pageview DF does not have the '/products' prefix, we need to get rid of it in the product DF.

# %%
products.link = products.link.str.replace(r'/products', '')

# %%
products.shape
# Out:
# (144, 9)

# %%
sales.shape
# Out:
# (143, 5)

# %%
pageviews.shape
# Out:
# (143, 4)

# %%
product_views = pd.merge(products, pageviews, left_on='link', right_on='path', how='outer')

# %%
product_views.head()
# Out:
#                                                 name  ...                                               path
# 0  Kopfkissen Bio Lotus Natural®, Bio-Baumwolle k...  ...                                                NaN
# 1  Geschirrtuch aus Halbleinen mit Bio-Baumwolle ...  ...                                                NaN
# 2                                      Feueranzünder  ...              /41162-feueranzuender-if-you-care-iyc
# 3          Duschseife Milchsamt BIO - mit Kokosmilch  ...  /186601-duschseife-milchsamt-bio-mit-kokosmilc...
# 4                       Bio Schoko-Kürbis Zartbitter  ...    /49787-bio-schoko-kuerbis-zartbitter-landgarten
#
# [5 rows x 13 columns]

# %%
product_views.shape
# Out:
# (244, 13)

# %%
for index, row in product_views.iterrows():
  print('Link: {}\nPath: {}\nLink==Path: {}\n{}'.format(row.link,
                                                     row.path,
                                                     row.link==row.path,
                                                     '*'*60))
# Out:
# Link: /128594-kopfkissen-bio-lotus-natural-r-bio-baumwolle-kba-fuellung-kapokfaser-lotus-natural-r?variant_id=932804
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /201249-geschirrtuch-aus-halbleinen-mit-bio-baumwolle-50-x-70-cm-aspegren?variant_id=1560821
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /41162-feueranzuender-if-you-care-iyc
# Path: /41162-feueranzuender-if-you-care-iyc
# Link==Path: True
# ************************************************************
# Link: /186601-duschseife-milchsamt-bio-mit-kokosmilch-asavo-1
# Path: /186601-duschseife-milchsamt-bio-mit-kokosmilch-asavo-1
# Link==Path: True
# ************************************************************
# Link: /49787-bio-schoko-kuerbis-zartbitter-landgarten
# Path: /49787-bio-schoko-kuerbis-zartbitter-landgarten
# Link==Path: True
# ************************************************************
# Link: /208453-saatgutkonfetti-kompostierbares-konfetti-das-saatgut-24-heimischer-wild-pflanzenarten-enthaelt-saatgutkonfetti?variant_id=1697669
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /96254-spork-bambus-mini-besteck-fuer-unterwegs-bambu
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /198723-3er-vorratspack-lemongras-seife-naturkosmetik-zertifiziert-biologisch-abbaubar-hydrophil
# Path: /198723-3er-vorratspack-lemongras-seife-naturkosmetik-zertifiziert-biologisch-abbaubar-hydrophil
# Link==Path: True
# ************************************************************
# Link: /194120-costa-rica-cola-el-puente
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /74236-rasierpinsel-kunsthaar-mit-olivenholzgriff-vegan-olivenholz-erleben
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /221340-22-tuerchen-bluetooth-box-kreafunk?variant_id=1743177
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /152740-glas-trinkhalme-glas-strohhalme-trinkhalm-glas-plus-buerste-6st-215cm-ecoyou
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /209325-veganes-kaugummi-himbeere-vanille-true-gum
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /207040-6x-gerade-metallstrohhalme-strich-plastikfreie-trinkhalme-inkl-reinigungsbuerste-und-tragetasche-skojig?variant_id=1623587
# Path: /207040-6x-gerade-metallstrohhalme-strich-plastikfreie-trinkhalme-inkl-reinigungsbuerste-und-tragetasche-skojig?variant_id=1623587
# Link==Path: True
# ************************************************************
# Link: /200793-dessertteller-elsa-tranquillo
# Path: /200793-dessertteller-elsa-tranquillo
# Link==Path: True
# ************************************************************
# Link: /43560-schafmilch-seife-herz-saling-naturprodukte
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /144074-ras-el-hanout-bio-gewuerzmischung-mill-und-mortar
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /197524-becher-elsa-tranquillo
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /174876-bio-saatgut-box-fuer-das-ganze-jahr-jahresbox-gartenjahr-rankwerk
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /193124-blumenwiese-fuer-bienen-wunderle
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /221778-kork-untersetzer-fuer-toepfe-korkuntersetzer-3er-set-living-in-kork
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /178284-saisonkalender-obst-und-gemuese-poster-strich-plakat-in-farbe-kupferstecher-punkt-art?variant_id=1379359
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /209459-cafe-de-paris-gewuerzmischung-50g-bio-soulspice
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /190622-kaesemesser-mit-handgriff-aus-olivenholz-olivenholz-erleben
# Path: /190622-kaesemesser-mit-handgriff-aus-olivenholz-olivenholz-erleben
# Link==Path: True
# ************************************************************
# Link: /140538-halm-strohhalme-aus-glas-trinkhalme-3x-23-cm-gebogen-plus-3x-20-cm-gerade-plus-reinigungsbuerste-halm
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /157860-sonnenglas-r-classic-solarlampe-sonnenglas
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /164731-biocase-smartphone-huelle-aus-nachhaltigem-bio-material-woodcessories?variant_id=1767957
# Path: /164731-biocase-smartphone-huelle-aus-nachhaltigem-bio-material-woodcessories?variant_id=1767957
# Link==Path: True
# ************************************************************
# Link: /75288-green-und-fair-gummihandschuhe-strich-haushaltshandschuhe-aus-fsc-zertifiziertem-naturkautschuk-green-und-fair?variant_id=683950
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /105019-passiertuch-fuer-die-vegane-milch-naturtasche
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /209190-showerbit-festes-duschgel-meeresfrische-60g-rosenrot-naturkosmetik
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /220800-kinder-maus-zahnbuerste-aus-bambus-extra-weich-orange-hydrophil?variant_id=1735375
# Path: /220800-kinder-maus-zahnbuerste-aus-bambus-extra-weich-orange-hydrophil?variant_id=1735375
# Link==Path: True
# ************************************************************
# Link: /221782-kokosfaser-kokos-schwamm-fuer-die-kueche-oder-das-bad-gaia-1
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /135558-nachhaltige-bambus-zahnbuersten-im-4er-sparset-99pandas
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /186602-duschseife-zitronenfit-bio-mit-zitronengras-und-minze-asavo
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /201249-geschirrtuch-aus-halbleinen-mit-bio-baumwolle-50-x-70-cm-aspegren?variant_id=1560818
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /202498-fester-conditioner-allergenfrei-in-schachtel-60g-rosenrot-naturkosmetik
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /140525-halm-glasstrohhalme-trinkhalme-6x-15-cm-gerade-plus-reinigungsbuerste-halm
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /209430-goldene-milch-gewuerzmix-fuer-getraenke-50g-bio-soulspice
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /230462-interdentalbuersten-aus-bambus-6-stueck-nachhaltige-zahnpflege-ecoyou?variant_id=1828663
# Path: /230462-interdentalbuersten-aus-bambus-6-stueck-nachhaltige-zahnpflege-ecoyou?variant_id=1828663
# Link==Path: True
# ************************************************************
# Link: /194125-kau-fair-el-puente
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /192215-nefsu-bamboo-brush-i-aktivkohle-mittelweiche-borsten-i-vegan-und-bpa-frei-nefsu-no-excuse-for-single-use
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /186607-duschseife-lavendelzeit-bio-lavendelseife-asavo
# Path: /186607-duschseife-lavendelzeit-bio-lavendelseife-asavo
# Link==Path: True
# ************************************************************
# Link: /103943-vegane-zahnbuerste-bpa-frei-biobrush-berlin?variant_id=765792
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /191579-fruehstuecksglas-mit-loeffel-350-ml-kilner
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /222370-tuerstopper-aus-holz-katze-mitienda-shop
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /74563-olivenoel-seife-olive-olivenholz-erleben
# Path: /74563-olivenoel-seife-olive-olivenholz-erleben
# Link==Path: True
# ************************************************************
# Link: /207407-5-spices-wokgemuese-45g-bio-soulspice
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /202425-festes-shampoo-honig-55g-rosenrot-naturkosmetik
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /197251-tasse-daphne-tranquillo
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /208562-redaav-2-punkt-0-tc-aa-unisex-behelfs-mund-nasen-maske-aus-bio-baumwoll-mix-armedangels?variant_id=1632369
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /202444-festes-shampoo-kornblumen-zitronen-55g-rosenrot-naturkosmetik
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /189108-schafmilchseife-rose-pink-bdih-zertifiziert-saling-naturprodukte
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /176890-spielkarten-doppelkopf-das-gendergerechte-kartendeck-spielkoepfe
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /230703-vogelfutterhaus-mini-motiv-speisekammer-wunderle
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /202452-festes-shampoo-kokos-55g-rosenrot-naturkosmetik
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /140526-halm-glasstrohhalme-trinkhalme-6x-23-cm-gerade-plus-reinigungsbuerste-halm
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /230313-natural-und-friendly-seife-palmoelfrei-hopery?variant_id=1827619
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /186606-duschseife-rosmarinkraft-bio-rosmarinseife-asavo
# Path: /186606-duschseife-rosmarinkraft-bio-rosmarinseife-asavo
# Link==Path: True
# ************************************************************
# Link: /37645-meinwoody-baum-pflanzset-meinwoody?variant_id=691760
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /230148-nummer-herbalist-starter-kit-3er-kraeuter-blumen-pflanzset-meinwoody
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /222388-avoidwaste-sisal-saeckchen-avoidwaste-1
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /63246-bioboy-r-veganer-universalreiniger-bioboy
# Path: /63246-bioboy-r-veganer-universalreiniger-bioboy
# Link==Path: True
# ************************************************************
# Link: /179089-stifte-aus-recyceltem-zeitungspapier-12x-pandoo?variant_id=1385096
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /105910-halm-trinkhalme-glasstrohhalme-4x-23-cm-gerade-plus-reinigungsbuerste-halm?variant_id=774727
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /200751-suppenteller-elsa-tranquillo
# Path: /200751-suppenteller-elsa-tranquillo
# Link==Path: True
# ************************************************************
# Link: /165061-grusskarte-mit-umschlag-el-puente?variant_id=1306680
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /213717-vegane-zahnseide-im-plastikfreien-glasflakon-30-meter-minzgeschmack-mit-bambus-aktivkohle-ecoyou
# Path: /213717-vegane-zahnseide-im-plastikfreien-glasflakon-30-meter-minzgeschmack-mit-bambus-aktivkohle-ecoyou
# Link==Path: True
# ************************************************************
# Link: /137686-postkarte-friendship-bow-und-hummingbird
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /223177-soulspice-holy-greek-gewuerzmischung-soulspice
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /172254-sofakissen-grautoene-haengemattenglueck?variant_id=1331946
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /188348-upcycling-glas-2er-set-in-2-groessen-und-2-farben-originalhome?variant_id=1445159
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /128788-soulbottle-06l-glastrinkflasche-verschiedene-motive-soulbottles?variant_id=932920
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /207041-6x-geknickte-metallstrohhalme-strich-plastikfreie-trinkhalme-inkl-reinigungsbuerste-und-tragetasche-skojig?variant_id=1623596
# Path: /207041-6x-geknickte-metallstrohhalme-strich-plastikfreie-trinkhalme-inkl-reinigungsbuerste-und-tragetasche-skojig?variant_id=1623596
# Link==Path: True
# ************************************************************
# Link: /177868-3er-pack-wachspapier-bienenwachstuecher-fuer-lebensmittel-bambuswald-11?variant_id=1375246
# Path: /177868-3er-pack-wachspapier-bienenwachstuecher-fuer-lebensmittel-bambuswald-11?variant_id=1375246
# Link==Path: True
# ************************************************************
# Link: /208480-plastikfreie-zahnbuerste-fuer-kinder-aus-bambus-im-4er-set-bambuswald
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /27187-urban-gardening-kraeutertoepfe-italienische-kraeuter-aries
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /74567-saatkugeln-bienenweide-aries
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /223021-vitamin-b12-tropfen-50ml-gk-nutrition
# Path: /223021-vitamin-b12-tropfen-50ml-gk-nutrition
# Link==Path: True
# ************************************************************
# Link: /194299-essbare-blueten-saatgut-box-s-bio-im-papp-geschenkkarton-saatgut-dillmann
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /195391-pizzaschneider-mit-griff-aus-olivenholz-olivenholz-erleben
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /134468-kuechenset-3-tlg-wender-kochloeffel-und-risottoloeffel-olivenholz-erleben
# Path: /134468-kuechenset-3-tlg-wender-kochloeffel-und-risottoloeffel-olivenholz-erleben
# Link==Path: True
# ************************************************************
# Link: /202328-fester-conditioner-reichhaltig-60g-rosenrot-naturkosmetik
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /126217-aries-bausatz-samen-bomben-mit-bio-saatgut-aries
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /220609-3er-set-glasbehaelter-vorratsglaeser-mit-luftdichten-deckel-aus-bambus-in-vielen-groessen-bambuswald?variant_id=1734413
# Path: /220609-3er-set-glasbehaelter-vorratsglaeser-mit-luftdichten-deckel-aus-bambus-in-vielen-groessen-bambuswald?variant_id=1734413
# Link==Path: True
# ************************************************************
# Link: /172393-sofakissen-rottoene-haengemattenglueck?variant_id=1333832
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /107212-efie-waermflasche-mit-seehund-applikation-kba-organic-efie
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /74250-gemuese-strich-schaelmesser-mit-gerader-klinge-mit-olivenholzgriff-olivenholz-erleben
# Path: /74250-gemuese-strich-schaelmesser-mit-gerader-klinge-mit-olivenholzgriff-olivenholz-erleben
# Link==Path: True
# ************************************************************
# Link: /187111-10-waschbare-abschminkpads-aus-bio-sweat-und-bio-frottee-plus-waeschenetz-treu?variant_id=1432618
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /13960-pflanzen-in-der-dose-gluecksklee-macflowers
# Path: /13960-pflanzen-in-der-dose-gluecksklee-macflowers
# Link==Path: True
# ************************************************************
# Link: /151181-biologisch-abbaubare-hundekotbeutel-ohne-henkel-8-x-15-stueck-the-sustainable-people
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /185978-metall-fotobox-mit-klarsichtdeckel-10x15-cm-bilderdose-fotoalbum-dose-ds-1
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /105451-veganes-einkaufsnetz-aus-biobaumwolle-fesch-und-fair
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /74559-olivenoel-seife-aprikose-olivenholz-erleben
# Path: /74559-olivenoel-seife-aprikose-olivenholz-erleben
# Link==Path: True
# ************************************************************
# Link: /145226-ecoyou-r-rasierhobel-10-klingen-nassrasierer-rasierer-damen-und-herren-ecoyou
# Path: /145226-ecoyou-r-rasierhobel-10-klingen-nassrasierer-rasierer-damen-und-herren-ecoyou
# Link==Path: True
# ************************************************************
# Link: /225001-besteckkasten-aus-bambus-fuer-schubladen-groessenverstellbar-bambuswald
# Path: /225001-besteckkasten-aus-bambus-fuer-schubladen-groessenverstellbar-bambuswald
# Link==Path: True
# ************************************************************
# Link: /178061-saisonkalender-obst-und-gemuese-poster-strich-plakat-in-schwarz-weiss-kupferstecher-punkt-art?variant_id=1377559
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /104699-zahnbuersten-halter-blau-hydrophil-1
# Path: /104699-zahnbuersten-halter-blau-hydrophil-1
# Link==Path: True
# ************************************************************
# Link: /64308-denttabs-zahnputztabletten-mit-fluorid-denttabs-r
# Path: /64308-denttabs-zahnputztabletten-mit-fluorid-denttabs-r
# Link==Path: True
# ************************************************************
# Link: /201131-fruehstuecksteller-merle-tranquillo
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /143063-bienenwachstuch-starter-set-s-strich-m-strich-l-gaia?variant_id=1433070
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /223042-gaia-bienenwachstuecher-3er-starter-set-bodil-jane-jungle-edition-set-s-strich-m-strich-l-gaia
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /172593-bambus-zahnbuersten-4er-set-vegane-holzzahnbuerste-borsten-mittel-ecoyou
# Path: /172593-bambus-zahnbuersten-4er-set-vegane-holzzahnbuerste-borsten-mittel-ecoyou
# Link==Path: True
# ************************************************************
# Link: /118673-bio-bienenwachstuch-klein-15x15-cm-little-bee-fresh?variant_id=1071724
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /224167-regalmodul-room-in-a-box-room-in-a-box
# Path: /224167-regalmodul-room-in-a-box-room-in-a-box
# Link==Path: True
# ************************************************************
# Link: /208407-langer-pfeffer-ganz-50g-bio-soulspice
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /172254-sofakissen-grautoene-haengemattenglueck?variant_id=1331948
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /223041-gaia-bienenwachstuecher-3er-set-bodil-jane-female-edition-s-strich-m-strich-l-gaia
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /226132-101-sorten-saisonkalender-obst-und-gemuese-in-farbe-kupferstecher-punkt-art
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /212689-zimt-orangen-seife-fuer-koerper-und-haar-naturkosmetik-zertifiziert-limitierte-edition-hydrophil
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /197050-sitzkissen-stay-tranquillo
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /13894-pflanzen-in-der-dose-edelweiss-bavaria-macflowers
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /164731-biocase-smartphone-huelle-aus-nachhaltigem-bio-material-woodcessories?variant_id=1767956
# Path: /164731-biocase-smartphone-huelle-aus-nachhaltigem-bio-material-woodcessories?variant_id=1767956
# Link==Path: True
# ************************************************************
# Link: /218045-der-a2-wandkalender-2021-kleinwaren-strich-von-laufenberg
# Path: /218045-der-a2-wandkalender-2021-kleinwaren-strich-von-laufenberg
# Link==Path: True
# ************************************************************
# Link: /74233-crepes-wender-aus-olivenholz-olivenholz-erleben
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /48309-lemongras-seife-fuer-koerper-und-haar-naturkosmetik-zertifiziert-hydrophil
# Path: /48309-lemongras-seife-fuer-koerper-und-haar-naturkosmetik-zertifiziert-hydrophil
# Link==Path: True
# ************************************************************
# Link: /107387-halm-trinkhalm-aus-glas-23-cm-4x-glastrinkhalm-plus-reinigungsbuerste-halm?variant_id=781379
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /200984-brotschneidebrett-aus-100-prozent-bambus-schneidebrett-brotbrett-schneideunterlage-bambuswald
# Path: /200984-brotschneidebrett-aus-100-prozent-bambus-schneidebrett-brotbrett-schneideunterlage-bambuswald
# Link==Path: True
# ************************************************************
# Link: /133220-hirschgeweih-geweihstueck-fuer-hunde-ganz-naftie?variant_id=963760
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /198216-kuechenhandschuh-polly-aus-biobaumwolle-gots-zertifiziert-tranquillo-1
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /146141-essbare-blumen-bluetenmischung-anzuchtset-mit-7-sorten-in-der-dose-macflowers
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /109666-duftkerze-juniper-munio-candela
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /40832-fussmassage-mit-acht-metallachsen-biodora
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /201309-40x60-cm-kapok-bio-kopfkissen-vegan-mit-separatem-innenbeutel-koma-schlafgut
# Path: /201309-40x60-cm-kapok-bio-kopfkissen-vegan-mit-separatem-innenbeutel-koma-schlafgut
# Link==Path: True
# ************************************************************
# Link: /198287-halm-glasstrohhalme-6x-20-cm-gebogen-trinkhalme-aus-glas-halm
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /221343-spuelschwamm-aus-luffa-100-prozent-plastikfrei-und-kompostierbar-naiked
# Path: /221343-spuelschwamm-aus-luffa-100-prozent-plastikfrei-und-kompostierbar-naiked
# Link==Path: True
# ************************************************************
# Link: /141679-kaesehobel-design-aus-olivenholz-olivenholz-erleben
# Path: /141679-kaesehobel-design-aus-olivenholz-olivenholz-erleben
# Link==Path: True
# ************************************************************
# Link: /207118-schwarzer-knoblauch-bio-schwarzer-knoblauch?variant_id=1624687
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /201472-selbstreinigendes-bio-case-smartphone-huelle-aus-antibakteriellem-und-nachhaltigem-bio-material-woodcessories?variant_id=1562286
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /81854-zahnbuersten-etui-hydrophil
# Path: /81854-zahnbuersten-etui-hydrophil
# Link==Path: True
# ************************************************************
# Link: /77761-2-tlg-set-pfannenwender-und-kochloeffel-aus-olivenholz-olivenholz-erleben
# Path: /77761-2-tlg-set-pfannenwender-und-kochloeffel-aus-olivenholz-olivenholz-erleben
# Link==Path: True
# ************************************************************
# Link: /40096-olivenbaum-als-geschenk-schenkeinbaeumchen
# Path: /40096-olivenbaum-als-geschenk-schenkeinbaeumchen
# Link==Path: True
# ************************************************************
# Link: /223144-bernstein-glas-sojawachs-kerze-120ml-duftkerze-in-verschiedenen-duftrichtungen-gartda?variant_id=1763964
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /74561-olivenoel-seife-milch-olivenholz-erleben
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /134518-briefoeffner-aus-olivenholz-olivenholz-erleben
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /172539-3er-set-sandwich-und-snacktaschen-brotbeutel-save-the-jungle-the-sustainables
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /177931-bienenwachstuecher-auf-rolle-100x33cm-wiederverwendbare-wachstuecher-skojig-1
# Path: /177931-bienenwachstuecher-auf-rolle-100x33cm-wiederverwendbare-wachstuecher-skojig-1
# Link==Path: True
# ************************************************************
# Link: /201472-selbstreinigendes-bio-case-smartphone-huelle-aus-antibakteriellem-und-nachhaltigem-bio-material-woodcessories?variant_id=1581223
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /213794-ecoyou-vegane-zahnseide-nachfuellset-2-x-30-meter-rollen-mit-minzgeschmack-aus-bambus-aktivkohle-ecoyou
# Path: /213794-ecoyou-vegane-zahnseide-nachfuellset-2-x-30-meter-rollen-mit-minzgeschmack-aus-bambus-aktivkohle-ecoyou
# Link==Path: True
# ************************************************************
# Link: /202449-festes-shampoo-melisse-hanf-55g-rosenrot-naturkosmetik
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /176295-bulgarische-joghurtkulturen-naturjoghurt-selber-machen-bacillus-bulgaricus
# Path: /176295-bulgarische-joghurtkulturen-naturjoghurt-selber-machen-bacillus-bulgaricus
# Link==Path: True
# ************************************************************
# Link: /223037-soulspice-sweet-kashmir-mango-curry-gewuerzmix-soulspice
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /182279-baumschmuck-aus-holz-verschiedene-motive-mitienda-shop?variant_id=1834334
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /11529-mousepad-aus-recyceltem-leder-vireo?variant_id=79857
# Path: nan
# Link==Path: False
# ************************************************************
# Link: /184966-handcreme-fest-biokosmetik-biologisch-regional-plastikfrei-4peoplewhocare?variant_id=1747360
# Path: nan
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /220612-xl-set-vorratsglaeser-aus-glas-mit-deckel-aus-100-prozent-bambus-in-4-groessen-bambuswald
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /203165-wiederverwendbarer-lebensmittelbeutel-large-26-x-215cm-192-liter-stasher-bag?variant_id=1580229
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /42933-farbige-mehrweg-becher-300-ml-aus-baumsaft-nowaste?variant_id=640814
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /133941-hibiskustee-70g-el-puente
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /230500-parsa-vita-seifen-saeckchen-parsa-vita
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /50001-spueltuch-disktrasa-vaexbo-lin?variant_id=970393
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /212359-dokumentenablage-aus-100-prozent-bambus-zeitschriftensammler-aufbewahrung-von-dokumenten-bambuswald
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /42933-farbige-mehrweg-becher-300-ml-aus-baumsaft-nowaste?variant_id=640813
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /198791-geschirrtuch-lara-biobaumwolle-gots-zertifiziert-50-x-70-cm-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /30138-schneidebrett-biodora
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201995-hochwertiges-seifensaeckchen-aus-bio-sisal-mit-baumwollschlaufe-ecoyou
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /51497-sack-aus-altpapier-kolor
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /137665-postkarte-ho-ho-ho-bow-und-hummingbird
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /68652-anti-stress-kugeln-in-box-im-2er-set-aus-olivenholz-olivenholz-erleben
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201841-zahnbuerstenhalter-naila-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /77815-pfannenwender-ohne-loecher-aus-olivenholz-olivenholz-erleben
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /208415-green-umami-gewuerzmischung-50g-soulspice
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /33173-topfbuerste-mit-ergonomisch-geformten-holzgriff-biodora
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /209189-showerbit-festes-duschgel-mandelbluete-60g-rosenrot-naturkosmetik
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /200796-schale-elsa-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201268-seifenschale-nicole-petrol-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /78560-naturtasche-als-obst-und-gemuesebeutel-20x26cm-naturtasche
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /87029-neti-r-nasenspuelkaennchen-neti-r?variant_id=684164
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /220240-nussmilchbeutel-fuer-pflanzliche-milch-aus-bio-baumwolle-filtertuch-passiertuch-nut-milk-bag-1stk-punkt-ecodis
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /220178-mix-5er-set-dekokugel-klein-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /144641-rotweinsalz-bio-mill-und-mortar
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /185007-tischset-butter-bei-die-fische-bow-und-hummingbird
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /90691-oeko-spuelschwamm-sonett
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /74562-olivenoel-seife-rose-olivenholz-erleben
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /43270-bleistift-zum-einpflanzen-sprout?variant_id=261922
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /230676-4er-set-rechteckige-glasbox-mit-bambusdeckel-370ml-640ml-1040ml-1520ml-auflaufform-ofenform-bambuswald
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201090-duftoellampe-clara-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /202457-festes-shampoo-walnuss-mandel-55g-rosenrot-naturkosmetik
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /41118-backpapier-24-zugeschnittene-blaetter-if-you-care-iyc
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /198021-40x80-cm-kapok-bio-kopfkissen-vegan-mit-separatem-innenbeutel-koma-schlafgut
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /72975-kochloeffel-rund-30-cm-aus-olivenholz-olivenholz-erleben
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /208515-seife-chia-seed-strich-grapefruit-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /230508-parsa-beauty-edelsteinroller-rosenquarz-parsa-beauty
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /177263-stoffbinde-tagesbinde-plus-waschbar-aus-bio-baumwolle-1-stueck-ecofemme-strich-bio-stoffbinden?variant_id=1380275
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /74074-living-crafts-badematte-living-crafts?variant_id=935469
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /211852-recycelter-baumwollteppich-paris-liv-interior?variant_id=1652465
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /221773-luffa-schwamm-3er-set-kuechenschwamm-bzw-spuelschwamm-fuer-die-kueche-zum-spuelen-und-putzen-gaia
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /50027-zahnbuerste-aus-bambus-4erpack-mittelweich-gruen-hydrophil?variant_id=521598
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /203166-wiederverwendbarer-lebensmittelbeutel-stand-up-215-x-18cm-16-liter-stasher-bag?variant_id=1580240
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /158139-guppyfriend-waschbeutel-guppyfriend
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /203293-pflanzenbasierte-zahnseide-tio
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /97225-wiederverwendbare-kuechenrolle-aus-bambus-viskose-pandoo?variant_id=727798
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /224274-alltagsmaske-in-gruen-schwarz-mit-blueten-zweilagig-aus-bio-baumwolle-widda-berlin?variant_id=1764844
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /187326-topfhalter-polly-aus-biobaumwolle-gots-zertifiziert-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /211909-handcreme-vegan-und-fest-naturkosmetik-biologisch-regional-plastikfrei-4peoplewhocare?variant_id=1747468
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /200007-oekologisches-insektenhaus-mit-metalldach-bienenhotel-insektenhotel-nuetzlingshotel-bambuswald
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /164380-bienenwachstuch-repair-wachs-gaia
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /159693-ecoyou-r-rasierklingen-100er-set-ersatzklingen-klingen-fuer-rasierhobel-ecoyou
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /9237-bio-kefir-strich-milchkefir-drink-mit-kefirknollen-mittel-wellness-drinks
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /202900-zwitscherbox-relaxsound?variant_id=1577697
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /185005-tischset-moin-bow-und-hummingbird
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /223096-frischhaltedose-rund-07l-15l-oder-25l-greenline?variant_id=1763772
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201354-waschbare-taschentuecher-5er-pack-imse-vimse?variant_id=1561690
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /199459-seifenspender-lyse-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /153908-fair-zone-gartenhandschuhe-fairzone?variant_id=1210587
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /140518-halm-glasstrohhalme-6x-20-cm-gerade-halm
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /230675-10er-set-gewuerzglaeser-jeweils-150ml-volumen-gewuerzbehaelter-glasdose-vorratsdose-bambuswald
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /56084-zahnbuerste-aus-bambus-4erpack-mittelweich-natur-hydrophil
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /194765-rasierhobel-klassik-mit-griff-watzmann-aus-olivenholz-olivenholz-erleben
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201271-seifenschale-fleur-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /87207-teigroller-strich-nudelholz-design-kurz-ca-25-cm-aus-olivenholz-olivenholz-erleben
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /151188-hundekotbeutel-aus-recyceltem-pe-50-stueck-am-block-tieraerzte-pool
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /208742-seifenschale-nicole-heaven-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /60956-seifenschale-oval-klein-aus-olivenholz-olivenholz-erleben
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201110-quicheform-louise-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /210174-fairphone-3-plus-plus-fairphone?variant_id=1646802
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /198132-timor-rasierklingen-rostfrei-10-stueck-unverpackt-giesen-und-forsthoff
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201138-kaennchen-merle-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /198981-oekologisches-schwammtuch-spueltuch-in-versch-designs-groovygoods?variant_id=1667850
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /220625-waeschesammler-mit-integrierten-waeschesack-ca-615x425x315cm-waeschetruhe-aus-bambus-und-mit-deckel-bambuswald
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /213576-fermentations-starter-kit-fairment
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201133-essteller-merle-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /230678-3er-set-rechteckige-glasbox-640ml-1040ml-1520ml-auflaufform-ofenform-lasagneform-bambuswald
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /163198-klappbares-abtropfgestell-fuer-geschirr-100-prozent-bambus-bambuswald?variant_id=1293647
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /230161-behelfs-mund-nasen-maske-schwarz-roka-fair-clothing?variant_id=1822566
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /124446-2er-pack-obst-und-gemuesenetz-living-crafts
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /220681-set-kanne-plus-stoevchen-flora-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /218687-schreibtischunterlage-aus-kork-eckig-mehrfarbig-corkando-strich-home?variant_id=1745648
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /214674-coconut-candle-holder-i-kokosnuss-teelichthalter-balu-bowls?variant_id=1693356
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /177255-bio-stoffbinden-full-cycle-kit-7-stueck-ecofemme-strich-bio-stoffbinden
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /162307-12-abschminkpads-waschbar-aus-bambus-viskose-bambudo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /198602-behelfs-mund-nasen-maske-aus-bio-baumwolle-unisex-und-schadstofffrei-gemaess-gots-zertifizierung-melawear?variant_id=1830113
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /176884-spielkarten-skat-das-gendergerechte-kartendeck-spielkoepfe
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /26284-schreibtischunterlagen-set-aus-recyceltem-leder-imtc?variant_id=179439
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /199442-ablage-lou-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /179007-seifenablage-aus-porzellan-und-holz-mitienda-shop
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /212343-edelstahl-thermosflasche-750ml-bambusliebe?variant_id=1700766
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /118517-rapslicht-fuer-glaeser-im-3er-set-ohne-duft-stuwa
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201045-butterdose-greta-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201321-fairphone-3-protective-case-auch-fuer-fairphone-3-plus-fairphone?variant_id=1561430
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /163106-oekologisches-bambus-schneidebrett-in-s-bis-xl-mit-abtropfrinne-bambuswald-1?variant_id=1293409
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /188348-upcycling-glas-2er-set-in-2-groessen-und-2-farben-originalhome?variant_id=1445158
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /201047-butterdose-marie-tranquillo
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /112581-bio-bienenwachstuch-gross-35x35-cm-little-bee-fresh?variant_id=1354253
# Link==Path: False
# ************************************************************
# Link: nan
# Path: /72810-kraeuter-und-schneidebrett-30-cm-als-2er-set-aus-olivenholz-olivenholz-erleben
# Link==Path: False
# ************************************************************

# %%
for index, row in product_views.iterrows():
  if row.link!=row.path:
    print('{}\n{}'.format(row.link, row.path))
# Out:
# /128594-kopfkissen-bio-lotus-natural-r-bio-baumwolle-kba-fuellung-kapokfaser-lotus-natural-r?variant_id=932804
# nan
# /201249-geschirrtuch-aus-halbleinen-mit-bio-baumwolle-50-x-70-cm-aspegren?variant_id=1560821
# nan
# /208453-saatgutkonfetti-kompostierbares-konfetti-das-saatgut-24-heimischer-wild-pflanzenarten-enthaelt-saatgutkonfetti?variant_id=1697669
# nan
# /96254-spork-bambus-mini-besteck-fuer-unterwegs-bambu
# nan
# /194120-costa-rica-cola-el-puente
# nan
# /74236-rasierpinsel-kunsthaar-mit-olivenholzgriff-vegan-olivenholz-erleben
# nan
# /221340-22-tuerchen-bluetooth-box-kreafunk?variant_id=1743177
# nan
# /152740-glas-trinkhalme-glas-strohhalme-trinkhalm-glas-plus-buerste-6st-215cm-ecoyou
# nan
# /209325-veganes-kaugummi-himbeere-vanille-true-gum
# nan
# /43560-schafmilch-seife-herz-saling-naturprodukte
# nan
# /144074-ras-el-hanout-bio-gewuerzmischung-mill-und-mortar
# nan
# /197524-becher-elsa-tranquillo
# nan
# /174876-bio-saatgut-box-fuer-das-ganze-jahr-jahresbox-gartenjahr-rankwerk
# nan
# /193124-blumenwiese-fuer-bienen-wunderle
# nan
# /221778-kork-untersetzer-fuer-toepfe-korkuntersetzer-3er-set-living-in-kork
# nan
# /178284-saisonkalender-obst-und-gemuese-poster-strich-plakat-in-farbe-kupferstecher-punkt-art?variant_id=1379359
# nan
# /209459-cafe-de-paris-gewuerzmischung-50g-bio-soulspice
# nan
# /140538-halm-strohhalme-aus-glas-trinkhalme-3x-23-cm-gebogen-plus-3x-20-cm-gerade-plus-reinigungsbuerste-halm
# nan
# /157860-sonnenglas-r-classic-solarlampe-sonnenglas
# nan
# /75288-green-und-fair-gummihandschuhe-strich-haushaltshandschuhe-aus-fsc-zertifiziertem-naturkautschuk-green-und-fair?variant_id=683950
# nan
# /105019-passiertuch-fuer-die-vegane-milch-naturtasche
# nan
# /209190-showerbit-festes-duschgel-meeresfrische-60g-rosenrot-naturkosmetik
# nan
# /221782-kokosfaser-kokos-schwamm-fuer-die-kueche-oder-das-bad-gaia-1
# nan
# /135558-nachhaltige-bambus-zahnbuersten-im-4er-sparset-99pandas
# nan
# /186602-duschseife-zitronenfit-bio-mit-zitronengras-und-minze-asavo
# nan
# /201249-geschirrtuch-aus-halbleinen-mit-bio-baumwolle-50-x-70-cm-aspegren?variant_id=1560818
# nan
# /202498-fester-conditioner-allergenfrei-in-schachtel-60g-rosenrot-naturkosmetik
# nan
# /140525-halm-glasstrohhalme-trinkhalme-6x-15-cm-gerade-plus-reinigungsbuerste-halm
# nan
# /209430-goldene-milch-gewuerzmix-fuer-getraenke-50g-bio-soulspice
# nan
# /194125-kau-fair-el-puente
# nan
# /192215-nefsu-bamboo-brush-i-aktivkohle-mittelweiche-borsten-i-vegan-und-bpa-frei-nefsu-no-excuse-for-single-use
# nan
# /103943-vegane-zahnbuerste-bpa-frei-biobrush-berlin?variant_id=765792
# nan
# /191579-fruehstuecksglas-mit-loeffel-350-ml-kilner
# nan
# /222370-tuerstopper-aus-holz-katze-mitienda-shop
# nan
# /207407-5-spices-wokgemuese-45g-bio-soulspice
# nan
# /202425-festes-shampoo-honig-55g-rosenrot-naturkosmetik
# nan
# /197251-tasse-daphne-tranquillo
# nan
# /208562-redaav-2-punkt-0-tc-aa-unisex-behelfs-mund-nasen-maske-aus-bio-baumwoll-mix-armedangels?variant_id=1632369
# nan
# /202444-festes-shampoo-kornblumen-zitronen-55g-rosenrot-naturkosmetik
# nan
# /189108-schafmilchseife-rose-pink-bdih-zertifiziert-saling-naturprodukte
# nan
# /176890-spielkarten-doppelkopf-das-gendergerechte-kartendeck-spielkoepfe
# nan
# /230703-vogelfutterhaus-mini-motiv-speisekammer-wunderle
# nan
# /202452-festes-shampoo-kokos-55g-rosenrot-naturkosmetik
# nan
# /140526-halm-glasstrohhalme-trinkhalme-6x-23-cm-gerade-plus-reinigungsbuerste-halm
# nan
# /230313-natural-und-friendly-seife-palmoelfrei-hopery?variant_id=1827619
# nan
# /37645-meinwoody-baum-pflanzset-meinwoody?variant_id=691760
# nan
# /230148-nummer-herbalist-starter-kit-3er-kraeuter-blumen-pflanzset-meinwoody
# nan
# /222388-avoidwaste-sisal-saeckchen-avoidwaste-1
# nan
# /179089-stifte-aus-recyceltem-zeitungspapier-12x-pandoo?variant_id=1385096
# nan
# /105910-halm-trinkhalme-glasstrohhalme-4x-23-cm-gerade-plus-reinigungsbuerste-halm?variant_id=774727
# nan
# /165061-grusskarte-mit-umschlag-el-puente?variant_id=1306680
# nan
# /137686-postkarte-friendship-bow-und-hummingbird
# nan
# /223177-soulspice-holy-greek-gewuerzmischung-soulspice
# nan
# /172254-sofakissen-grautoene-haengemattenglueck?variant_id=1331946
# nan
# /188348-upcycling-glas-2er-set-in-2-groessen-und-2-farben-originalhome?variant_id=1445159
# nan
# /128788-soulbottle-06l-glastrinkflasche-verschiedene-motive-soulbottles?variant_id=932920
# nan
# /208480-plastikfreie-zahnbuerste-fuer-kinder-aus-bambus-im-4er-set-bambuswald
# nan
# /27187-urban-gardening-kraeutertoepfe-italienische-kraeuter-aries
# nan
# /74567-saatkugeln-bienenweide-aries
# nan
# /194299-essbare-blueten-saatgut-box-s-bio-im-papp-geschenkkarton-saatgut-dillmann
# nan
# /195391-pizzaschneider-mit-griff-aus-olivenholz-olivenholz-erleben
# nan
# /202328-fester-conditioner-reichhaltig-60g-rosenrot-naturkosmetik
# nan
# /126217-aries-bausatz-samen-bomben-mit-bio-saatgut-aries
# nan
# /172393-sofakissen-rottoene-haengemattenglueck?variant_id=1333832
# nan
# /107212-efie-waermflasche-mit-seehund-applikation-kba-organic-efie
# nan
# /187111-10-waschbare-abschminkpads-aus-bio-sweat-und-bio-frottee-plus-waeschenetz-treu?variant_id=1432618
# nan
# /151181-biologisch-abbaubare-hundekotbeutel-ohne-henkel-8-x-15-stueck-the-sustainable-people
# nan
# /185978-metall-fotobox-mit-klarsichtdeckel-10x15-cm-bilderdose-fotoalbum-dose-ds-1
# nan
# /105451-veganes-einkaufsnetz-aus-biobaumwolle-fesch-und-fair
# nan
# /178061-saisonkalender-obst-und-gemuese-poster-strich-plakat-in-schwarz-weiss-kupferstecher-punkt-art?variant_id=1377559
# nan
# /201131-fruehstuecksteller-merle-tranquillo
# nan
# /143063-bienenwachstuch-starter-set-s-strich-m-strich-l-gaia?variant_id=1433070
# nan
# /223042-gaia-bienenwachstuecher-3er-starter-set-bodil-jane-jungle-edition-set-s-strich-m-strich-l-gaia
# nan
# /118673-bio-bienenwachstuch-klein-15x15-cm-little-bee-fresh?variant_id=1071724
# nan
# /208407-langer-pfeffer-ganz-50g-bio-soulspice
# nan
# /172254-sofakissen-grautoene-haengemattenglueck?variant_id=1331948
# nan
# /223041-gaia-bienenwachstuecher-3er-set-bodil-jane-female-edition-s-strich-m-strich-l-gaia
# nan
# /226132-101-sorten-saisonkalender-obst-und-gemuese-in-farbe-kupferstecher-punkt-art
# nan
# /212689-zimt-orangen-seife-fuer-koerper-und-haar-naturkosmetik-zertifiziert-limitierte-edition-hydrophil
# nan
# /197050-sitzkissen-stay-tranquillo
# nan
# /13894-pflanzen-in-der-dose-edelweiss-bavaria-macflowers
# nan
# /74233-crepes-wender-aus-olivenholz-olivenholz-erleben
# nan
# /107387-halm-trinkhalm-aus-glas-23-cm-4x-glastrinkhalm-plus-reinigungsbuerste-halm?variant_id=781379
# nan
# /133220-hirschgeweih-geweihstueck-fuer-hunde-ganz-naftie?variant_id=963760
# nan
# /198216-kuechenhandschuh-polly-aus-biobaumwolle-gots-zertifiziert-tranquillo-1
# nan
# /146141-essbare-blumen-bluetenmischung-anzuchtset-mit-7-sorten-in-der-dose-macflowers
# nan
# /109666-duftkerze-juniper-munio-candela
# nan
# /40832-fussmassage-mit-acht-metallachsen-biodora
# nan
# /198287-halm-glasstrohhalme-6x-20-cm-gebogen-trinkhalme-aus-glas-halm
# nan
# /207118-schwarzer-knoblauch-bio-schwarzer-knoblauch?variant_id=1624687
# nan
# /201472-selbstreinigendes-bio-case-smartphone-huelle-aus-antibakteriellem-und-nachhaltigem-bio-material-woodcessories?variant_id=1562286
# nan
# /223144-bernstein-glas-sojawachs-kerze-120ml-duftkerze-in-verschiedenen-duftrichtungen-gartda?variant_id=1763964
# nan
# /74561-olivenoel-seife-milch-olivenholz-erleben
# nan
# /134518-briefoeffner-aus-olivenholz-olivenholz-erleben
# nan
# /172539-3er-set-sandwich-und-snacktaschen-brotbeutel-save-the-jungle-the-sustainables
# nan
# /201472-selbstreinigendes-bio-case-smartphone-huelle-aus-antibakteriellem-und-nachhaltigem-bio-material-woodcessories?variant_id=1581223
# nan
# /202449-festes-shampoo-melisse-hanf-55g-rosenrot-naturkosmetik
# nan
# /223037-soulspice-sweet-kashmir-mango-curry-gewuerzmix-soulspice
# nan
# /182279-baumschmuck-aus-holz-verschiedene-motive-mitienda-shop?variant_id=1834334
# nan
# /11529-mousepad-aus-recyceltem-leder-vireo?variant_id=79857
# nan
# /184966-handcreme-fest-biokosmetik-biologisch-regional-plastikfrei-4peoplewhocare?variant_id=1747360
# nan
# nan
# /220612-xl-set-vorratsglaeser-aus-glas-mit-deckel-aus-100-prozent-bambus-in-4-groessen-bambuswald
# nan
# /203165-wiederverwendbarer-lebensmittelbeutel-large-26-x-215cm-192-liter-stasher-bag?variant_id=1580229
# nan
# /42933-farbige-mehrweg-becher-300-ml-aus-baumsaft-nowaste?variant_id=640814
# nan
# /133941-hibiskustee-70g-el-puente
# nan
# /230500-parsa-vita-seifen-saeckchen-parsa-vita
# nan
# /50001-spueltuch-disktrasa-vaexbo-lin?variant_id=970393
# nan
# /212359-dokumentenablage-aus-100-prozent-bambus-zeitschriftensammler-aufbewahrung-von-dokumenten-bambuswald
# nan
# /42933-farbige-mehrweg-becher-300-ml-aus-baumsaft-nowaste?variant_id=640813
# nan
# /198791-geschirrtuch-lara-biobaumwolle-gots-zertifiziert-50-x-70-cm-tranquillo
# nan
# /30138-schneidebrett-biodora
# nan
# /201995-hochwertiges-seifensaeckchen-aus-bio-sisal-mit-baumwollschlaufe-ecoyou
# nan
# /51497-sack-aus-altpapier-kolor
# nan
# /137665-postkarte-ho-ho-ho-bow-und-hummingbird
# nan
# /68652-anti-stress-kugeln-in-box-im-2er-set-aus-olivenholz-olivenholz-erleben
# nan
# /201841-zahnbuerstenhalter-naila-tranquillo
# nan
# /77815-pfannenwender-ohne-loecher-aus-olivenholz-olivenholz-erleben
# nan
# /208415-green-umami-gewuerzmischung-50g-soulspice
# nan
# /33173-topfbuerste-mit-ergonomisch-geformten-holzgriff-biodora
# nan
# /209189-showerbit-festes-duschgel-mandelbluete-60g-rosenrot-naturkosmetik
# nan
# /200796-schale-elsa-tranquillo
# nan
# /201268-seifenschale-nicole-petrol-tranquillo
# nan
# /78560-naturtasche-als-obst-und-gemuesebeutel-20x26cm-naturtasche
# nan
# /87029-neti-r-nasenspuelkaennchen-neti-r?variant_id=684164
# nan
# /220240-nussmilchbeutel-fuer-pflanzliche-milch-aus-bio-baumwolle-filtertuch-passiertuch-nut-milk-bag-1stk-punkt-ecodis
# nan
# /220178-mix-5er-set-dekokugel-klein-tranquillo
# nan
# /144641-rotweinsalz-bio-mill-und-mortar
# nan
# /185007-tischset-butter-bei-die-fische-bow-und-hummingbird
# nan
# /90691-oeko-spuelschwamm-sonett
# nan
# /74562-olivenoel-seife-rose-olivenholz-erleben
# nan
# /43270-bleistift-zum-einpflanzen-sprout?variant_id=261922
# nan
# /230676-4er-set-rechteckige-glasbox-mit-bambusdeckel-370ml-640ml-1040ml-1520ml-auflaufform-ofenform-bambuswald
# nan
# /201090-duftoellampe-clara-tranquillo
# nan
# /202457-festes-shampoo-walnuss-mandel-55g-rosenrot-naturkosmetik
# nan
# /41118-backpapier-24-zugeschnittene-blaetter-if-you-care-iyc
# nan
# /198021-40x80-cm-kapok-bio-kopfkissen-vegan-mit-separatem-innenbeutel-koma-schlafgut
# nan
# /72975-kochloeffel-rund-30-cm-aus-olivenholz-olivenholz-erleben
# nan
# /208515-seife-chia-seed-strich-grapefruit-tranquillo
# nan
# /230508-parsa-beauty-edelsteinroller-rosenquarz-parsa-beauty
# nan
# /177263-stoffbinde-tagesbinde-plus-waschbar-aus-bio-baumwolle-1-stueck-ecofemme-strich-bio-stoffbinden?variant_id=1380275
# nan
# /74074-living-crafts-badematte-living-crafts?variant_id=935469
# nan
# /211852-recycelter-baumwollteppich-paris-liv-interior?variant_id=1652465
# nan
# /221773-luffa-schwamm-3er-set-kuechenschwamm-bzw-spuelschwamm-fuer-die-kueche-zum-spuelen-und-putzen-gaia
# nan
# /50027-zahnbuerste-aus-bambus-4erpack-mittelweich-gruen-hydrophil?variant_id=521598
# nan
# /203166-wiederverwendbarer-lebensmittelbeutel-stand-up-215-x-18cm-16-liter-stasher-bag?variant_id=1580240
# nan
# /158139-guppyfriend-waschbeutel-guppyfriend
# nan
# /203293-pflanzenbasierte-zahnseide-tio
# nan
# /97225-wiederverwendbare-kuechenrolle-aus-bambus-viskose-pandoo?variant_id=727798
# nan
# /224274-alltagsmaske-in-gruen-schwarz-mit-blueten-zweilagig-aus-bio-baumwolle-widda-berlin?variant_id=1764844
# nan
# /187326-topfhalter-polly-aus-biobaumwolle-gots-zertifiziert-tranquillo
# nan
# /211909-handcreme-vegan-und-fest-naturkosmetik-biologisch-regional-plastikfrei-4peoplewhocare?variant_id=1747468
# nan
# /200007-oekologisches-insektenhaus-mit-metalldach-bienenhotel-insektenhotel-nuetzlingshotel-bambuswald
# nan
# /164380-bienenwachstuch-repair-wachs-gaia
# nan
# /159693-ecoyou-r-rasierklingen-100er-set-ersatzklingen-klingen-fuer-rasierhobel-ecoyou
# nan
# /9237-bio-kefir-strich-milchkefir-drink-mit-kefirknollen-mittel-wellness-drinks
# nan
# /202900-zwitscherbox-relaxsound?variant_id=1577697
# nan
# /185005-tischset-moin-bow-und-hummingbird
# nan
# /223096-frischhaltedose-rund-07l-15l-oder-25l-greenline?variant_id=1763772
# nan
# /201354-waschbare-taschentuecher-5er-pack-imse-vimse?variant_id=1561690
# nan
# /199459-seifenspender-lyse-tranquillo
# nan
# /153908-fair-zone-gartenhandschuhe-fairzone?variant_id=1210587
# nan
# /140518-halm-glasstrohhalme-6x-20-cm-gerade-halm
# nan
# /230675-10er-set-gewuerzglaeser-jeweils-150ml-volumen-gewuerzbehaelter-glasdose-vorratsdose-bambuswald
# nan
# /56084-zahnbuerste-aus-bambus-4erpack-mittelweich-natur-hydrophil
# nan
# /194765-rasierhobel-klassik-mit-griff-watzmann-aus-olivenholz-olivenholz-erleben
# nan
# /201271-seifenschale-fleur-tranquillo
# nan
# /87207-teigroller-strich-nudelholz-design-kurz-ca-25-cm-aus-olivenholz-olivenholz-erleben
# nan
# /151188-hundekotbeutel-aus-recyceltem-pe-50-stueck-am-block-tieraerzte-pool
# nan
# /208742-seifenschale-nicole-heaven-tranquillo
# nan
# /60956-seifenschale-oval-klein-aus-olivenholz-olivenholz-erleben
# nan
# /201110-quicheform-louise-tranquillo
# nan
# /210174-fairphone-3-plus-plus-fairphone?variant_id=1646802
# nan
# /198132-timor-rasierklingen-rostfrei-10-stueck-unverpackt-giesen-und-forsthoff
# nan
# /201138-kaennchen-merle-tranquillo
# nan
# /198981-oekologisches-schwammtuch-spueltuch-in-versch-designs-groovygoods?variant_id=1667850
# nan
# /220625-waeschesammler-mit-integrierten-waeschesack-ca-615x425x315cm-waeschetruhe-aus-bambus-und-mit-deckel-bambuswald
# nan
# /213576-fermentations-starter-kit-fairment
# nan
# /201133-essteller-merle-tranquillo
# nan
# /230678-3er-set-rechteckige-glasbox-640ml-1040ml-1520ml-auflaufform-ofenform-lasagneform-bambuswald
# nan
# /163198-klappbares-abtropfgestell-fuer-geschirr-100-prozent-bambus-bambuswald?variant_id=1293647
# nan
# /230161-behelfs-mund-nasen-maske-schwarz-roka-fair-clothing?variant_id=1822566
# nan
# /124446-2er-pack-obst-und-gemuesenetz-living-crafts
# nan
# /220681-set-kanne-plus-stoevchen-flora-tranquillo
# nan
# /218687-schreibtischunterlage-aus-kork-eckig-mehrfarbig-corkando-strich-home?variant_id=1745648
# nan
# /214674-coconut-candle-holder-i-kokosnuss-teelichthalter-balu-bowls?variant_id=1693356
# nan
# /177255-bio-stoffbinden-full-cycle-kit-7-stueck-ecofemme-strich-bio-stoffbinden
# nan
# /162307-12-abschminkpads-waschbar-aus-bambus-viskose-bambudo
# nan
# /198602-behelfs-mund-nasen-maske-aus-bio-baumwolle-unisex-und-schadstofffrei-gemaess-gots-zertifizierung-melawear?variant_id=1830113
# nan
# /176884-spielkarten-skat-das-gendergerechte-kartendeck-spielkoepfe
# nan
# /26284-schreibtischunterlagen-set-aus-recyceltem-leder-imtc?variant_id=179439
# nan
# /199442-ablage-lou-tranquillo
# nan
# /179007-seifenablage-aus-porzellan-und-holz-mitienda-shop
# nan
# /212343-edelstahl-thermosflasche-750ml-bambusliebe?variant_id=1700766
# nan
# /118517-rapslicht-fuer-glaeser-im-3er-set-ohne-duft-stuwa
# nan
# /201045-butterdose-greta-tranquillo
# nan
# /201321-fairphone-3-protective-case-auch-fuer-fairphone-3-plus-fairphone?variant_id=1561430
# nan
# /163106-oekologisches-bambus-schneidebrett-in-s-bis-xl-mit-abtropfrinne-bambuswald-1?variant_id=1293409
# nan
# /188348-upcycling-glas-2er-set-in-2-groessen-und-2-farben-originalhome?variant_id=1445158
# nan
# /201047-butterdose-marie-tranquillo
# nan
# /112581-bio-bienenwachstuch-gross-35x35-cm-little-bee-fresh?variant_id=1354253
# nan
# /72810-kraeuter-und-schneidebrett-30-cm-als-2er-set-aus-olivenholz-olivenholz-erleben

# %% [markdown]
# It seems that there is a huge number of articles for which we do not have pageview data. It took me quite some time to figure out why it is so---then I remembered: I produced the pageview data on other day than when I produced the CSV file listing products, so it is effectively based on a different selection of products---it appears that there is either some randomness about what products are appearing first on the homepage of Avocadostore, or the selection is updated periodically.
#
# I thought about updating both files to make them compatible, but then I decided against it. It is usually the case that different files we have do not match perfectly. It is sometimes the case that we have more missing values than actually present values when we combine two different files. Let's truncate the new merged file (the pageview data for products which we do not have in the product DF will not be necessary), and replace the missing values with 0s.

# %%
product_views = product_views[:144]

# %%
product_views.shape
# Out:
# (144, 13)

# %%
# drop the path column, since it is the same as the link column
product_views = product_views.drop('path', axis=1)

# %%
# fill nan values with zeroes
product_views = product_views.fillna(0)

# %%
product_views.tail()
# Out:
#                                                   name  ... time_on_page
# 139  Bulgarische Joghurtkulturen - Naturjoghurt sel...  ...        764.0
# 140      SoulSpice Sweet Kashmir Mango Curry Gewürzmix  ...          0.0
# 141          Baumschmuck aus Holz, verschiedene Motive  ...          0.0
# 142                      Mousepad aus recyceltem Leder  ...          0.0
# 143  Handcreme (fest) | Biokosmetik | Biologisch | ...  ...          0.0
#
# [5 rows x 12 columns]

# %% [markdown]
# Now we merge this dataframe with the sales data. This could possibly be more problematic, as I did some work on the product names so that they are not 100% compatible---and that before I knew that the titles are not compatible to start with!

# %%
df = pd.merge(product_views, sales, left_on='name', right_on='article_name', how='outer')

# %%
df.shape
# Out:
# (246, 17)

# %%
df.head()
# Out:
#                                                 name  ...                               article_name
# 0  Kopfkissen Bio Lotus Natural®, Bio-Baumwolle k...  ...                                        NaN
# 1  Geschirrtuch aus Halbleinen mit Bio-Baumwolle ...  ...                                        NaN
# 2  Geschirrtuch aus Halbleinen mit Bio-Baumwolle ...  ...                                        NaN
# 3                                      Feueranzünder  ...                              Feueranzünder
# 4          Duschseife Milchsamt BIO - mit Kokosmilch  ...  Duschseife Milchsamt BIO - mit Kokosmilch
#
# [5 rows x 17 columns]

# %% [markdown]
# Okay, so we need to manually do some searching to see if there are any product sales rows which we can salvage. This can be done manually---which is, in fact, how I would proceed most of the times, just looking at the articles which ended up with null values, looking out for what might've caused a problem. Just looking at the data often gives me some insight into what might've gone wrong.
#
# But let's speed up the process. Let's write a small loop which iterates through rows and, if it finds a row with empty article_name column, it iterates again to look for a row with article_name column with the same beginning as the name column which did not find a match. This should give us a sense of closure at least, even if we do not find any additional rows we can reconcile.

# %%
for index, row in df.iterrows():
  # check if article_name is NaN
  # DO NOT use the dot notation in this loop.
  # DOT NOTATION MIGHT CAUSE ERROR
  if pd.isnull(row['article_name']):
    # iterate through the dataframe again
    for index2, row2 in df.iterrows():
      # is the name column NaN?
      if pd.isnull(row2['name']):
        # are the beginning 5 characters of the first name and the
        # second article_name equivalent?
        if (row['name'][:5] == row2['article_name'][:5]):
          # print it it as a possible match
          print('Possible match: \n{}\nmight be equivalent to:\n{}\n{}\n'.format(
              row['name'], row2['article_name'], '*'*60
          ))
# Out:
# Possible match:
# Geschirrtuch aus Halbleinen mit Bio-Baumwolle 50 x 70 cm
# might be equivalent to:
# Geschirrtuch LARA, Biobaumwolle, GOTS-zertifiziert, 50 x 70 cm
# ************************************************************
#
# Possible match:
# Geschirrtuch aus Halbleinen mit Bio-Baumwolle 50 x 70 cm
# might be equivalent to:
# Geschirrtuch LARA, Biobaumwolle, GOTS-zertifiziert, 50 x 70 cm
# ************************************************************
#
# Possible match:
# Rasierpinsel KUNSTHAAR mit Olivenholzgriff (vegan)
# might be equivalent to:
# Rasierhobel KLASSIK mit Griff Watzmann aus Olivenholz
# ************************************************************
#
# Possible match:
# HALM Strohhalme aus Glas Trinkhalme 3x 23 cm (gebogen) + 3x 20 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# ShowerBit - festes Duschgel Meeresfrische - 60g
# might be equivalent to:
# ShowerBit - festes Duschgel Mandelblüte - 60g
# ************************************************************
#
# Possible match:
# fester Conditioner allergenfrei  |  in Schachtel 60g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# HALM Glasstrohhalme Trinkhalme 6x 15 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# Interdentalbürsten aus Bambus - 6 Stück - Nachhaltige Zahnpflege
# might be equivalent to:
# Interdentalbürsten aus Bambus — 6 Stück — Nachhaltige Zahnpflege
# ************************************************************
#
# Possible match:
# festes Shampoo Honig - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# festes Shampoo Kornblumen-Zitronen - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# Spielkarten - Doppelkopf - Das gendergerechte Kartendeck
# might be equivalent to:
# Spielkarten - Skat - Das gendergerechte Kartendeck
# ************************************************************
#
# Possible match:
# festes Shampoo Kokos - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# HALM Glasstrohhalme Trinkhalme 6x 23 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# Natural & Friendly Seife palmölfrei
# might be equivalent to:
# Naturtasche als Obst- & Gemüsebeutel (20x26cm)
# ************************************************************
#
# Possible match:
# HALM Trinkhalme Glasstrohhalme  4x 23 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# Postkarte Friendship
# might be equivalent to:
# Postkarte "Ho, ho, ho"
# ************************************************************
#
# Possible match:
# fester Conditioner Reichhaltig - 60g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# Bienenwachstuch Starter Set (S/M/L)
# might be equivalent to:
# Bienenwachstuch Repair-Wachs
# ************************************************************
#
# Possible match:
# Bio-Bienenwachstuch "Klein" - 15x15 cm
# might be equivalent to:
# Bio-Bienenwachstuch "Groß" - 35x35 cm
# ************************************************************
#
# Possible match:
# Pflanzen in der Dose - Edelweiss Bavaria
# might be equivalent to:
# Pflanzenbasierte Zahnseide
# ************************************************************
#
# Possible match:
# HALM Trinkhalm aus Glas 23 cm 4x Glastrinkhalm + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# HALM Glasstrohhalme  6x 20 cm (gebogen) Trinkhalme aus Glas
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# Olivenöl-Seife MILCH
# might be equivalent to:
# Olivenöl-Seife ROSE
# ************************************************************
#
# Possible match:
# 3er Set Sandwich- und Snacktaschen Brotbeutel - save the jungle
# might be equivalent to:
# 3er Set Rechteckige Glasbox 640ml 1040ml 1520ml - Auflaufform Ofenform Lasagneform
# ************************************************************
#
# Possible match:
# EcoYou Vegane Zahnseide - Nachfüllset - 2 x 30 Meter Rollen mit Minzgeschmack aus Bambus Aktivkohle
# might be equivalent to:
# EcoYou® Rasierklingen 100er Set | Ersatzklingen Klingen für Rasierhobel
# ************************************************************
#
# Possible match:
# EcoYou Vegane Zahnseide - Nachfüllset - 2 x 30 Meter Rollen mit Minzgeschmack aus Bambus Aktivkohle
# might be equivalent to:
# EcoYou Vegane Zahnseide — Nachfüllset — 2 x 30 Meter Rollen mit Minzgeschmack aus Bambus Aktivkohle
# ************************************************************
#
# Possible match:
# festes Shampoo Melisse-Hanf - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# Handcreme (fest) | Biokosmetik | Biologisch | Regional | Plastikfrei
# might be equivalent to:
# Handcreme (vegan & fest) | Naturkosmetik | Biologisch | Regional | Plastikfrei
# ************************************************************

# %% [markdown]
# This is quite successful. It seems that there are two articles where the names are not compatible because of a different hyphen character used in the two dataframes---we should do something about the 'EcoYou Vegane Zahnseide' and the 'Interdentalbürsten aus Bambus' articles. I propose to alter the original sales data, replacing the '—' character with the '-' character, making them mutually compatible; then we can merge the two dataframes again. We won't rerun the above function, we will just check the dimensions of the resulting dataframe to see if the two extra rows disappeared.

# %%
sales.article_name = sales.article_name.str.replace(r'—', '-')

# %%
df_improved = pd.merge(product_views, sales, left_on='name', right_on='article_name', how='outer')

# %%
df.shape
# Out:
# (246, 17)

# %%
df_improved.shape
# Out:
# (245, 17)

# %% [markdown]
# Well, one row indeed disappeared. What about the other? I must've missed something...

# %%
for index, row in df_improved.iterrows():
  # check if article_name is NaN
  # DO NOT use the dot notation in this loop.
  # DOT NOTATION MIGHT CAUSE ERROR
  if pd.isnull(row['article_name']):
    # iterate through the dataframe again
    for index2, row2 in df_improved.iterrows():
      # is the name column NaN?
      if pd.isnull(row2['name']):
        # are the beginning 5 characters of the first name and the
        # second article_name equivalent?
        if (row['name'][:5] == row2['article_name'][:5]):
          # print it it as a possible match
          print('Possible match: \n{}\nmight be equivalent to:\n{}\n{}\n'.format(
              row['name'], row2['article_name'], '*'*60
          ))
# Out:
# Possible match:
# Geschirrtuch aus Halbleinen mit Bio-Baumwolle 50 x 70 cm
# might be equivalent to:
# Geschirrtuch LARA, Biobaumwolle, GOTS-zertifiziert, 50 x 70 cm
# ************************************************************
#
# Possible match:
# Geschirrtuch aus Halbleinen mit Bio-Baumwolle 50 x 70 cm
# might be equivalent to:
# Geschirrtuch LARA, Biobaumwolle, GOTS-zertifiziert, 50 x 70 cm
# ************************************************************
#
# Possible match:
# Rasierpinsel KUNSTHAAR mit Olivenholzgriff (vegan)
# might be equivalent to:
# Rasierhobel KLASSIK mit Griff Watzmann aus Olivenholz
# ************************************************************
#
# Possible match:
# HALM Strohhalme aus Glas Trinkhalme 3x 23 cm (gebogen) + 3x 20 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# ShowerBit - festes Duschgel Meeresfrische - 60g
# might be equivalent to:
# ShowerBit - festes Duschgel Mandelblüte - 60g
# ************************************************************
#
# Possible match:
# fester Conditioner allergenfrei  |  in Schachtel 60g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# HALM Glasstrohhalme Trinkhalme 6x 15 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# festes Shampoo Honig - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# festes Shampoo Kornblumen-Zitronen - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# Spielkarten - Doppelkopf - Das gendergerechte Kartendeck
# might be equivalent to:
# Spielkarten - Skat - Das gendergerechte Kartendeck
# ************************************************************
#
# Possible match:
# festes Shampoo Kokos - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# HALM Glasstrohhalme Trinkhalme 6x 23 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# Natural & Friendly Seife palmölfrei
# might be equivalent to:
# Naturtasche als Obst- & Gemüsebeutel (20x26cm)
# ************************************************************
#
# Possible match:
# HALM Trinkhalme Glasstrohhalme  4x 23 cm (gerade) + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# Postkarte Friendship
# might be equivalent to:
# Postkarte "Ho, ho, ho"
# ************************************************************
#
# Possible match:
# fester Conditioner Reichhaltig - 60g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# Bienenwachstuch Starter Set (S/M/L)
# might be equivalent to:
# Bienenwachstuch Repair-Wachs
# ************************************************************
#
# Possible match:
# Bio-Bienenwachstuch "Klein" - 15x15 cm
# might be equivalent to:
# Bio-Bienenwachstuch "Groß" - 35x35 cm
# ************************************************************
#
# Possible match:
# Pflanzen in der Dose - Edelweiss Bavaria
# might be equivalent to:
# Pflanzenbasierte Zahnseide
# ************************************************************
#
# Possible match:
# HALM Trinkhalm aus Glas 23 cm 4x Glastrinkhalm + Reinigungsbürste
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# HALM Glasstrohhalme  6x 20 cm (gebogen) Trinkhalme aus Glas
# might be equivalent to:
# HALM Glasstrohhalme  6x 20 cm (gerade)
# ************************************************************
#
# Possible match:
# Olivenöl-Seife MILCH
# might be equivalent to:
# Olivenöl-Seife ROSE
# ************************************************************
#
# Possible match:
# 3er Set Sandwich- und Snacktaschen Brotbeutel - save the jungle
# might be equivalent to:
# 3er Set Rechteckige Glasbox 640ml 1040ml 1520ml - Auflaufform Ofenform Lasagneform
# ************************************************************
#
# Possible match:
# festes Shampoo Melisse-Hanf - 55g
# might be equivalent to:
# festes Shampoo Walnuss-Mandel - 55g
# ************************************************************
#
# Possible match:
# Handcreme (fest) | Biokosmetik | Biologisch | Regional | Plastikfrei
# might be equivalent to:
# Handcreme (vegan & fest) | Naturkosmetik | Biologisch | Regional | Plastikfrei
# ************************************************************

# %% [markdown]
# Nah, I was paranoid. Both rows are now incorporated with the main dataframe. Let's truncate the main df and fill missing values with 0s, then we can export it to a CSV.

# %%
df_final = df_improved[:144]

# %%
# drop the path column, since it is the same as the link column
df_final = df_final.drop('article_name', axis=1)

# %%
# fill nan values with zeroes
df_final = df_final.fillna(0)

# %%
df_final.tail(2)
# Out:
#                                               name  ... average_revenue
# 142  SoulSpice Sweet Kashmir Mango Curry Gewürzmix  ...             0.0
# 143      Baumschmuck aus Holz, verschiedene Motive  ...             0.0
#
# [2 rows x 16 columns]

# %%
df_final.to_csv('merged_data.csv', index=False)
# !cp merged_data.csv "drive/My Drive/deite/avocado/"

# %% [markdown]
# And that's it---we have a neat CSV file with article information, descriptions, but also with pageview data and sales data, giving us some additional insights. The file we've produced is very imperfect---as we've seen before, there are many products which lack the pageview and sales data. This is of course an uncomfortable result---but it is also something that happens only too often when dealing with real-world data. I hope that this exercise was as interesting for you as it was for me.
